# %% [markdown]
# <a href="https://colab.research.google.com/github/abreuzzzz/Py_Mackenzie/blob/main/Tarefa1/Trilha1_Tarefa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
texto = []

f = open('/content/py.txt','r')    # para arquivos locais
for line in f:
    texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'o': 29, 'python': 25, 'foi': 15, 'concebido': 1, 'no': 6, 'final': 1, 'de': 60, '1989[6][9]': 1, 'por': 7, 'guido': 4, 'van': 1, 'rossum': 1, 'instituto': 1, 'pesquisa': 1, 'nacional': 1, 'para': 15, 'matemática': 1, 'e': 28, 'ciência': 1, 'da': 26, 'computação': 3, 'cwi': 4, 'nos': 2, 'países': 1, 'baixos': 1, 'como': 9, 'um': 8, 'sucessor': 1, 'abc': 3, 'capaz': 2, 'tratar': 2, 'exceções': 3, 'prover': 1, 'interface': 1, 'com': 13, 'sistema': 5, 'operacional': 2, 'amoeba[10]': 1, 'através': 1, 'scripts': 1, 'também': 6, 'a': 43, 'linguagem': 13, 'era': 5, 'mais': 4, 'produtiva': 1, 'que': 14, 'c': 3, 'ainda': 2, 'custo': 1, 'do': 14, 'desempenho': 1, 'em': 22, 'tempo': 1, 'execução': 1, 'mas': 1, 'ela': 1, 'não': 2, 'possuía': 1, 'funcionalidades': 2, 'importantes': 1, 'interação': 1, 'uma': 14, 'necessidade': 1, 'grupo': 3, 'dos': 3, 'focos': 1, 'primordiais': 1, 'aumentar': 1, 'produtividade': 1, 'programador[9]': 1, 'feita': 1, 'base': 2, 'na': 15, 'possui': 1, 'parte': 1, 'sintaxe': 3, 'derivada': 1, 'compreensão': 1, 'listas': 1, 'funções': 2, 'anonimas': 1, 'função': 2, 'map': 2, 'haskell': 4, 'os': 4, 'iteradores': 1, 'são': 1, 'baseados': 1, 'icon': 1, 'tratamentos': 1, 'exceção': 1, 'módulos': 2, 'modula-3': 3, 'expressões': 1, 'regulares': 1, 'perl': 1, '1991': 1, 'publicou': 1, 'código': 3, 'nomeado': 1, 'versão': 20, '090': 1, 'discussão': 2, 'altsources[1]': 1, 'nessa': 2, 'já': 4, 'estavam': 2, 'presentes': 1, 'classes': 2, 'herança': 1, 'tratamento': 1, 'tipos': 2, 'dado': 1, 'nativos': 1, 'list': 2, 'dict': 1, 'str': 1, 'assim': 3, 'diante': 1, 'estava': 3, 'presente': 1, 'emprestado': 1, 'modelo': 3, 'lembrava': 1, 'muito': 1, 'adição': 1, 'opção': 1, 'else': 1, 'clause[10]em': 1, '1994': 2, 'formado': 1, 'principal': 1, 'fórum': 1, 'complangpython': 1, 'marco': 1, 'crescimento': 1, 'usuários': 1, '10': 1, 'lançada': 5, 'janeiro': 1, 'novas': 1, 'incluíam': 1, 'ferramentas': 1, 'programação': 2, 'funcional': 1, 'lambda': 1, 'filter': 1, 'reduce': 1, 'última': 1, 'enquanto': 1, '12': 1, '1995': 1, 'ele': 1, 'continuou': 1, 'trabalho': 1, 'cnri': 5, 'reston': 1, 'estados': 1, 'unidos': 1, 'onde': 1, 'lançou': 2, 'diversas': 2, 'versões': 4, '14': 1, 'ganhou': 1, 'parâmetros': 2, 'nomeados': 1, 'capacidade': 1, 'passar': 1, 'parâmetro': 1, 'pelo': 1, 'nome': 2, 'pela': 3, 'posição': 1, 'lista': 1, 'suporte': 1, 'nativo': 1, 'números': 1, 'complexos': 1, 'forma': 2, 'encapsulamento[11]': 1, 'iniciativa': 1, 'computer': 1, 'programming': 1, 'for': 1, 'everybody': 1, 'cp4e;': 1, 'literalmente': 1, '"programação': 1, 'computadores': 1, 'todos"': 1, 'visava': 1, 'tornar': 1, 'acessível': 1, 'projeto': 1, 'financiado': 1, 'darpa[12]': 1, 'atualmente': 3, 'cp4e': 1, 'encontra-se': 1, 'inativo': 1, '2000': 1, 'time': 2, 'desenvolvimento': 3, 'se': 3, 'mudou': 1, 'beopen': 3, 'fim': 2, 'formar': 1, 'pythonlabs': 2, 'pediu': 1, '16': 2, 'fosse': 1, 'marcar': 1, 'naquele': 1, 'local': 1, 'único': 1, 'lançamento': 4, '20': 5, 'após': 1, 'desenvolvedores': 1, 'agrupou-se': 1, 'digital': 1, 'creations': 1, 'implementou': 1, 'comprehension': 1, 'relevante': 1, 'funcionalidade': 2, 'linguagens': 4, 'funcionais': 1, 'setl': 1, 'essa': 3, 'construção': 1, 'é': 6, 'bastante': 1, 'similar': 1, 'exceto': 2, 'preferência': 2, 'caracteres': 1, 'pontuação': 1, 'palavras': 1, 'reservadas': 1, 'alfabéticas': 1, 'introduziu': 1, 'coletor': 1, 'lixo': 1, 'identificar': 1, 'ciclos': 1, 'referências[13]': 1, 'incluiu': 2, 'licença': 7, 'substancialmente': 1, 'longa': 1, 'usando': 1, 'nas': 1, 'anteriores': 1, 'entre': 3, 'outras': 3, 'mudanças': 2, 'incluía': 1, 'cláusula': 1, 'atestando': 1, 'governada': 1, 'pelas': 1, 'leis': 1, 'virgínia': 1, 'free': 1, 'software': 4, 'foundation': 3, 'alegou': 1, 'isso': 2, 'incompatível': 1, 'gnu': 1, 'gpl': 2, 'tanto': 1, 'quanto': 1, 'fsf': 1, 'negociaram': 1, 'mudança': 3, 'livre': 1, 'tornaria': 1, 'compatível': 2, '161': 2, 'idêntico': 1, 'ao': 2, '160': 1, 'pequenas': 1, 'correções': 1, 'falhas ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
